# %%
import matplotlib.pyplot as plt
import csv
from GenerateInputSamples import smearings, fluctuate_data_size, n_bootstraps
import numpy as np
import pandas as pd
import seaborn as sns
import glob
import os

# %%
data_directory = 'fit_results/'
csv_files = glob.glob(os.path.join(data_directory, 'fit_results_*-v1*.csv'))
data_frames = []

for file in csv_files:
    df = pd.read_csv(file)
    filename = os.path.basename(file)
    smearing_str = filename.split('_')[2].split('-v1')[0]
    smearing = float(smearing_str)
    df['Smearing'] = smearing
    data_frames.append(df)

big_df = pd.concat(data_frames, ignore_index=True)
if 'Parameter' in big_df.columns:
    big_df = big_df[big_df['Parameter'] != 'A']
big_df.dropna(inplace = True)
big_df.drop(['Value', 'Error_Lower'], axis = 1, inplace = True)
big_df.rename(columns={"Error_Upper": "Error"}, inplace = True)

# %%
print(f"Combined DataFrame shape: {big_df.shape}")
# Out:
# Combined DataFrame shape: (39774, 5)

# %%
print("DataFrame columns:", big_df.columns.tolist())
print(big_df.describe())
# Out:
# DataFrame columns: ['Parameter', 'Error', 'Fit_Type', 'Bootstrap_Index', 'Smearing']
#               Error  Bootstrap_Index      Smearing
# count  39774.000000     39774.000000  39774.000000
# mean       1.262264       249.329461      0.374084
# std      243.789968       144.322883      0.227910
# min       -0.024753         0.000000      0.000000
# 25%        0.009255       124.000000      0.157900
# 50%        0.011618       249.000000      0.355300
# 75%        0.015738       374.000000      0.592100
# max    48619.123059       499.000000      0.750000

# %%
big_df['lower'] = big_df.groupby(['Smearing', 'Fit_Type', 'Parameter'])['Error'].transform(lambda x: x.quantile(0.1))
big_df['upper'] = big_df.groupby(['Smearing', 'Fit_Type', 'Parameter'])['Error'].transform(lambda x: x.quantile(0.9))

filtered_big_df = big_df[(big_df['Error'] >= big_df['lower']) & (big_df['Error'] <= big_df['upper'])]
mean_df = filtered_big_df.groupby(['Smearing', 'Fit_Type', 'Parameter'])['Error'].mean().reset_index()

# %%
print("DataFrame columns:", filtered_big_df.columns.tolist())
print(filtered_big_df.describe())
# Out:
# DataFrame columns: ['Parameter', 'Error', 'Fit_Type', 'Bootstrap_Index', 'Smearing', 'lower', 'upper']
#               Error  Bootstrap_Index      Smearing         lower         upper
# count  31810.000000     31810.000000  31810.000000  31810.000000  31810.000000
# mean       0.013257       250.697925      0.374021      0.012354      0.014485
# std        0.006590       143.845118      0.227909      0.005302      0.008230
# min        0.002945         0.000000      0.000000      0.002944      0.003386
# 25%        0.009239       127.000000      0.157900      0.009079      0.009351
# 50%        0.011585       251.000000      0.355300      0.011168      0.012123
# 75%        0.015639       375.000000      0.592100      0.015004      0.016998
# max        0.059068       499.000000      0.750000      0.029659      0.059353

# %%
mean_df = filtered_big_df.groupby(['Smearing', 'Fit_Type', 'Parameter'])['Error'].mean().reset_index()

# %%
parameters = ['mu', 'var']
fit_types = ['cov', 'cov_diag']

for parameter in parameters:
    plt.figure(figsize=(8, 6))
    for fit_type in fit_types:
        subset = mean_df[(mean_df['Parameter'] == parameter) & (mean_df['Fit_Type'] == fit_type)]
        plt.plot(subset['Smearing'], subset['Error'], marker='o', label=f'{parameter} ({fit_type})')
    plt.xlabel('Smearing')
    plt.ylabel(f'Mean Error of {parameter}')
    plt.title(f'Mean Error of {parameter} vs. Smearing')
    plt.legend()
    plt.grid(True)
    plt.show()
