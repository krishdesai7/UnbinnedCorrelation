# %%
import sys
original_sys_path = sys.path.copy()
sys.path.append('/global/home/users/krishdesai/UnbinnedCorrelation/')
from ConfidenceIntervalScript import *
sys.path = original_sys_path

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.size'] = 24

# %%
smearings = [1e-5, 0.25, 0.5, 0.75]
results = []

for smearing in smearings:
    print(f"Running with smearing: {smearing}")
    result = main(smearing=smearing)
    results.append(result)
# Out:
# Running with smearing: 1e-05
# Running with smearing: 0.010213877551020408
# Running with smearing: 0.020417755102040816
# Running with smearing: 0.030621632653061222
# Running with smearing: 0.040825510204081636
# Running with smearing: 0.051029387755102046
# Running with smearing: 0.06123326530612245
# Running with smearing: 0.07143714285714285
# Running with smearing: 0.08164102040816326
# Running with smearing: 0.09184489795918367
# Running with smearing: 0.10204877551020408
# Running with smearing: 0.11225265306122449
# Running with smearing: 0.12245653061224489
# Running with smearing: 0.13266040816326533
# Running with smearing: 0.14286428571428572
# Running with smearing: 0.15306816326530615
# Running with smearing: 0.16327204081632654
# Running with smearing: 0.17347591836734694
# Running with smearing: 0.18367979591836736
# Running with smearing: 0.19388367346938776
# Running with smearing: 0.20408755102040818
# Running with smearing: 0.21429142857142858
# Running with smearing: 0.224495306122449
# Running with smearing: 0.2346991836734694
# Running with smearing: 0.2449030612244898
# Running with smearing: 0.2551069387755102
# Running with smearing: 0.26531081632653064
# Running with smearing: 0.275514693877551
# Running with smearing: 0.28571857142857143
# Running with smearing: 0.29592244897959186
# Running with smearing: 0.3061263265306123
# Running with smearing: 0.31633020408163265
# Running with smearing: 0.3265340816326531
# Running with smearing: 0.3367379591836735
# Running with smearing: 0.34694183673469386
# Running with smearing: 0.3571457142857143
# Running with smearing: 0.3673495918367347
# Running with smearing: 0.37755346938775514
# Running with smearing: 0.3877573469387755
# Running with smearing: 0.39796122448979593
# Running with smearing: 0.40816510204081635
# Running with smearing: 0.4183689795918367
# Running with smearing: 0.42857285714285714
# Running with smearing: 0.43877673469387757
# Running with smearing: 0.448980612244898
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 6
#       4 for smearing in smearings:
#       5     print(f"Running with smearing: {smearing}")
# ----> 6     result = main(smearing=smearing)
#       7     results.append(result)
#
# File ~/UnbinnedCorrelation/ConfidenceIntervalScript.py:131, in main(smearing)
#     129     nll_min_diag = result_diag.fun  # Minimum NLL value
#     130     fitted_params_diag[i] = result_diag.x
# --> 131     intervals_diag[i, 0] = find_confidence_interval(neg_log_likelihood,
#     132                                            0, result_diag.x,
#     133                                            nll_min_diag,
#     134                                            bins,
#     135                                            unfolded_results_final[i],
#     136                                            cov_diag,
#     137                                            bounds)
#     138     intervals_diag[i, 1] = find_confidence_interval(neg_log_likelihood,
#     139                                               1,
#     140                                               result_diag.x,
#    (...)
#     144                                               cov_diag,
#     145                                               bounds)
#     146 return {
#     147     "full_cov": {
#     148         "mu": np.mean(fitted_params[:, 0]),
#    (...)
#     163     }
#     164 }
#
# File ~/UnbinnedCorrelation/ConfidenceIntervalScript.py:71, in find_confidence_interval(nll, param_index, param_value, nll_min, x, y, cov, bounds)
#      69     return nll(test_params, x, y, cov) - (nll_min + 0.5)
#      70 lower_bound = brentq(target_function, bounds[param_index][0], param_value[param_index])
# ---> 71 upper_bound = brentq(target_function, param_value[param_index], bounds[param_index][1])
#      72 return lower_bound, upper_bound
#
# File ~/anaconda3/envs/python3122/lib/python3.12/site-packages/scipy/optimize/_zeros_py.py:809, in brentq(f, a, b, args, xtol, rtol, maxiter, full_output, disp)
#     807     raise ValueError(f"rtol too small ({rtol:g} < {_rtol:g})")
#     808 f = _wrap_nan_raise(f)
# --> 809 r = _zeros._brentq(f, a, b, xtol, rtol, maxiter, args, full_output, disp)
#     810 return results_c(full_output, r, "brentq")
#
# ValueError: f(a) and f(b) must have different signs

# %%
full_cov = {}
diag_cov = {}

parameters = ['mu', 'sigma']
attributes = ['', 'sigma_on_', 'asy_']

for parameter in parameters:
    for attr in attributes:
        full_cov[attr + parameter] = [res['full_cov'][attr + parameter] for res in results]
        diag_cov[attr + parameter] = [res['diag_cov'][attr + parameter] for res in results]

# %%
full_cov_ratio = np.array(full_cov['sigma_on_mu']) / np.array(full_cov['asy_mu'])
diag_cov_ratio_full_asy = np.array(diag_cov['sigma_on_mu']) / np.array(full_cov['asy_mu'])
full_cov_ratio_diag_asy = np.array(full_cov['sigma_on_mu']) / np.array(diag_cov['asy_mu'])
diag_cov_ratio_diag_asy = np.array(diag_cov['sigma_on_mu']) / np.array(diag_cov['asy_mu'])

# Create a figure and a set of subplots with 1 row and 3 columns
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(20, 6))  # Expanding to three plots

# First subplot: Ratio of sigma_on_mu to asy_mu for full and diag cov
ax1.plot(smearings, full_cov_ratio, label='Full', marker='o', linestyle='-')
ax1.plot(smearings, diag_cov_ratio_diag_asy, label='Diag', marker='s', linestyle='--')
ax1.set_xlabel('Smearing')
ax1.set_ylabel('CI($\\mu$)/Asy($\\mu$)')
ax1.legend()
ax1.grid(True)
ax1.set_xlim(0, 0.5)
ax1.set_ylim(0, 2)

# Second subplot: Comparison of ratios using Full Cov asy_mu for both
ax2.plot(smearings, full_cov_ratio, label='Full', marker='o', linestyle='-')
ax2.plot(smearings, diag_cov_ratio_full_asy, label='Diag', marker='x', linestyle='-.')
ax2.set_xlabel('Smearing')
ax2.set_ylabel('Ratio to Full Asy($\\mu$)')
ax2.legend()
ax2.grid(True)
ax2.set_xlim(0, 0.5)
ax2.set_ylim(0, 2)

# Third subplot: Comparison of ratios using Diag Cov asy_mu for both
ax3.plot(smearings, full_cov_ratio_diag_asy, label='Full', marker='>', linestyle=':')
ax3.plot(smearings, diag_cov_ratio_diag_asy, label='Diag', marker='^', linestyle='-.')
ax3.set_xlabel('Smearing')
ax3.set_ylabel('Ratio to Diag Asy($\\mu$)')
ax3.legend()
ax3.grid(True)
ax3.set_xlim(0, 0.5)
ax3.set_ylim(0, 2)

plt.tight_layout()

plt.savefig('figures/mu_binned_corrs.pdf', bbox_inches='tight')
plt.show()

# %%
full_cov_ratio = np.array(full_cov['sigma_on_sigma']) / np.array(full_cov['asy_sigma'])
diag_cov_ratio_full_asy = np.array(diag_cov['sigma_on_sigma']) / np.array(full_cov['asy_sigma'])
full_cov_ratio_diag_asy = np.array(full_cov['sigma_on_sigma']) / np.array(diag_cov['asy_sigma'])
diag_cov_ratio_diag_asy = np.array(diag_cov['sigma_on_sigma']) / np.array(diag_cov['asy_sigma'])

# Create a figure and a set of subplots with 1 row and 3 columns
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(20, 6))  # Expanding to three plots

# First subplot: Ratio of sigma_on_sigma to asy_sigma for full and diag cov
ax1.plot(smearings, full_cov_ratio, label='Full', marker='o', linestyle='-')
ax1.plot(smearings, diag_cov_ratio_diag_asy, label='Diag', marker='s', linestyle='--')
ax1.set_xlabel('Smearing')
ax1.set_ylabel('CI($\\sigma$)/Asy($\\sigma$)')
ax1.legend()
ax1.grid(True)
ax1.set_xlim(0, 0.5)
ax1.set_ylim(0, 2)

# Second subplot: Comparison of ratios using Full Cov asy_sigma for both
ax2.plot(smearings, full_cov_ratio, label='Full', marker='o', linestyle='-')
ax2.plot(smearings, diag_cov_ratio_full_asy, label='Diag', marker='x', linestyle='-.')
ax2.set_xlabel('Smearing')
ax2.set_ylabel('Ratio to Full Asy($\\sigma$)')
ax2.legend()
ax2.grid(True)
ax2.set_xlim(0, 0.5)
ax2.set_ylim(0, 2)

# Third subplot: Comparison of ratios using Diag Cov asy_sigma for both
ax3.plot(smearings, full_cov_ratio_diag_asy, label='Full', marker='>', linestyle=':')
ax3.plot(smearings, diag_cov_ratio_diag_asy, label='Diag', marker='^', linestyle='-.')
ax3.set_xlabel('Smearing')
ax3.set_ylabel('Ratio to Diag Asy($\\sigma$)')
ax3.legend()
ax3.grid(True)
plt.xlim(0, 0.5)
plt.ylim(0, 2)
plt.tight_layout()

plt.show()
